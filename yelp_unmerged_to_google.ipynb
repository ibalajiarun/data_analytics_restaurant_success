# %%
from googleapiclient.discovery import build

# %%
service = build("customsearch", "v1",
            developerKey="AIzaSyDx1BTvgBnRtEsFwPmVZ9VcRDew5x6CtIU")

res =

# %%
def google_search(query):
    return service.cse().list(q=query,
      cx="006102967016578681648:zc2pgut5jok").execute()

# %%
res
# Out:
# {'context': {'title': 'Yelp'},
#  'items': [{'cacheId': 'W4Ngpq-n8TIJ',
#    'displayLink': 'www.yelp.com',
#    'formattedUrl': 'https://www.yelp.com/biz/dozo-japanese-cuisine-scottsdale',
#    'htmlFormattedUrl': 'https://www.yelp.com/biz/<b>dozo</b>-japanese-cuisine-<b>scottsdale</b>',
#    'htmlSnippet': '123 reviews of <b>Dozo</b> Japanese Cuisine - CLOSED &quot;Edit, Robert-san <b>and</b> Risa-<br>\nsan have opened their new location, called <b>Dozo</b> Izakaya, located at 440 W. <br>\nWarner <b>Rd</b> ... Photo of <b>Dozo</b> Japanese Cuisine - <b>Scottsdale</b>, <b>AZ</b>, United States. <br>\nveggie tempura Photo of <b>Dozo</b> Japanese Cuisine - <b>Scottsdale</b>, <b>AZ</b>, United States. <br>\nboba！',
#    'htmlTitle': '<b>Dozo</b> Japanese Cuisine - CLOSED - 43 Photos &amp; 123 Reviews ...',
#    'kind': 'customsearch#result',
#    'link': 'https://www.yelp.com/biz/dozo-japanese-cuisine-scottsdale',
#    'pagemap': {'aggregaterating': [{'ratingvalue': '4.0',
# ...

# %%
import requests

# %%
KEY = "JP-T0oiXNqqLi-sMu1_hD-9v1c95-4fMBI-4fI1clL5_gJeAp_oRR1GHatW3tyW3-PmCI7px8cDrDdXF8Yxr-83QkltoeYwmk-viJp7oCYQalGm-bY-V79pDbi_NWnYx"

# %%
 get_business(KEY, "dozo-japanese-cuisine-scottsdale")
# Out:
# Querying https://api.yelp.com/v3/businesses/dozo-japanese-cuisine-scottsdale ...
# {'alias': 'dozo-japanese-cuisine-scottsdale',
#  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#   {'alias': 'japanese', 'title': 'Japanese'}],
#  'coordinates': {'latitude': 33.4988781809807, 'longitude': -111.917583793402},
#  'display_phone': '(480) 941-3838',
#  'hours': [{'hours_type': 'REGULAR',
#    'is_open_now': False,
#    'open': [{'day': 0, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#     {'day': 0, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#     {'day': 1, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#     {'day': 1, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#     {'day': 2, 'end': '1430', 'is_overnight': False, 'start': '1130'},
#     {'day': 2, 'end': '2130', 'is_overnight': False, 'start': '1700'},
#     {'day': 3, 'end': '1430', 'is_overnight': False, 'start': '1130'},
# ...
